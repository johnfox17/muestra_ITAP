# %%
import pandas as pd
import matplotlib.pyplot as plt

import plotly.plotly as py
import plotly.tools as tls
import pylab

# %%
df = pd.read_csv('tfec_hemb.csv')

# %%
df.head()
# Out:
#    control  viv_sel  hogar  n_ren  renglon  ent  tloc  p5_11  p5_12  p5_13  \
# 0  3260005       12      1      2        1   32     4    1.0    2.0   13.0
# 1  3260005       13      1      2        1   32     4    1.0    2.0   10.0
# 2  3260005       14      1      2        1   32     4    1.0    2.0    3.0
# 3  3260005       15      1      3        1   32     4    2.0    2.0   24.0
# 4  3260005       16      1      2        1   32     4    1.0    1.0   22.0
#
#      ...     edad_1ag  c_limdisc  p3_12  niv  gra  cond_act  p10_1_ag  resemb  \
# 0    ...            9          3      2    2    6         2         1       1
# 1    ...            7          3      2    3    3         2         1       1
# 2    ...            6          3      2    3    3         2         1       1
# 3    ...           11          3      2    3    3         2         2       1
# 4    ...            9          3      2    3    3         2         1       1
#
#    ordenemb  ordenhnv
# 0         1       1.0
# 1         1       1.0
# 2         2       1.0
# 3         1       1.0
# 4         1       1.0
#
# [5 rows x 47 columns]

# %%
df2 = df['niv']

# %%
df3 =pd.Series.value_counts(df2)

# %%
type(df3)
# Out:
# pandas.core.series.Series

# %%
df4 = pd.DataFrame(df3)

# %%
df4.index.values
# Out:
# array([ 2,  3,  6,  8,  0,  5,  7, 10,  4,  9, 11,  1, 99], dtype=int64)

# %%
df5 = pd.DataFrame.reset_index(df4)

# %%
print(df5)
# Out:
#     index    niv
# 0       2  68926
# 1       3  68315
# 2       6  27018
# 3       8  18178
# 4       0  10036
# 5       5   6091
# 6       7   4536
# 7      10   1366
# 8       4    755
# 9       9    357
# 10     11    148
# 11      1     90
# 12     99      3

# %%
df6 = df5.drop(df5.index[[12]])

#df7 = pd.DataFrame.replace(df6[0][0],'Primaria')

# %%
print(df6)
# Out:
#     index    niv
# 0       2  68926
# 1       3  68315
# 2       6  27018
# 3       8  18178
# 4       0  10036
# 5       5   6091
# 6       7   4536
# 7      10   1366
# 8       4    755
# 9       9    357
# 10     11    148
# 11      1     90

# %%
barlist = plt.bar(df6['index'],df6['niv'])

barlist[0].set_color([.1,.2,.5])
barlist[1].set_color([.6,.2,.8])
barlist[2].set_color([.3,.1,.2])
barlist[3].set_color([.5,.8,.4])
barlist[4].set_color([.2,.5,.3])
barlist[5].set_color([.4,.7,.1])
barlist[6].set_color([.8,.6,.7])
barlist[7].set_color([.1,.3,.6])
barlist[8].set_color([.7,.9,.7])
pylab.xlim([0,15])
# Out:
# (0, 15)

# %%
plt.show()
